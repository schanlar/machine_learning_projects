# %% [markdown]
# # Download and save data in csv files

# %% [markdown]
# - Προκειμένου να διαχειριστούμε τα δεδομένα μας με μεγαλύτερη ευκολία, θα αποθηκεύσουμε σε δύο αρχεία csv τον όγκο των δεδομένων που θα χρησιμοποιήσουμε για την εκπαίδευση των μοντέλων μας, καθώς και τα δεδομένα στα οποία θα εφαρμόσουμε τα εν λόγω μοντέλα.

# %%
import pandas as pd
import glob
import re
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotify_config import config

# %% [markdown]
# - Αρχικά θα διαβάσουμε τα δεδομένα για κομμάτια που έχουν βρεθεί στις κορυφαίες θέσεις ακουσμάτων σε διάφορες χώρες για τα έτη 2017-2019.
#
#
#
# - Θα χρησιμοποιήσουμε αυτά τα κομμάτια για να αντλήσουμε πληροφορίες από το spotify όσον αφορά τα ακουστικά χαρακτηριστικά τους.
#
#
#
# - Θα αποθηκεύσουμε αυτά τα ακουστικά γνωρίσματα κάθε κομματιού σε ένα αρχείο ``train_data.csv``.
#
#
#
# - Βάσει αυτών των ακουστικών χαρακτηριστικών θα προσπαθήσουμε να φτιάξουμε μοντέλα που να προβλέπουν το σθένος ενός κομματιού.

# %%
# Read the data separately
# Concatenate each individual dataframe
# in a single one

header = 0 
dfs = []
for file in glob.glob('Charts/*/201?/*.csv'):
    
    weekly_chart = pd.read_csv(file, header=header, sep='\t')    
    dfs.append(weekly_chart)
    

all_charts = pd.concat(dfs)
all_charts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 273600 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   position            273600 non-null  int64
#  1   song_id             273600 non-null  object
#  2   song_name           273457 non-null  object
#  3   artist              273459 non-null  object
#  4   streams             273600 non-null  int64
#  5   last_week_position  238803 non-null  float64
#  6   weeks_on_chart      273600 non-null  int64
#  7   peak_position       273600 non-null  int64
#  8   position_status     273600 non-null  object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 20.9+ MB

# %% [markdown]
# - Σε αυτό το σύνολο δεδομένων υπάρχουν κομμάτια που εμφανίζονται πολλαπλές φορές στα charts.
#
#
#
# - Θα δημιουργήσουμε ένα καινούργιο ``DataFrame`` κρατώντας μόνο την πρώτη εμφάνιση ενός κομματιού στα charts και θα αντλήσουμε τα ακουστικά χαρακτηριστικά γι' αυτό το κομμάτι από το spotify.

# %%
# See how many unique songs our df contains
print('Unique song ids:', len(all_charts['song_id'].unique()))

# Keep only unique songs
all_charts = all_charts.drop_duplicates(subset=['song_id'])
# Out:
# Unique song ids: 13880

# %%
# Collect audio features for each song from spotify
client_credentials_manager = SpotifyClientCredentials(config['client_id'],
                                                     config['client_secret']
                                                     )

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# ------

features = {}

all_track_ids = list(all_charts['song_id'].unique())
start = 0 
num_tracks = 100
while start < len(all_track_ids):
    print('getting from {} to {}'.format(start, start+num_tracks))
    
    tracks_batch = all_track_ids[start:start+num_tracks]
    features_batch = sp.audio_features(tracks_batch)
    
    # Use dictionary comprehension to update dictionary's content
    features.update({track_id : track_features for track_id, track_features in zip(tracks_batch, features_batch)})
    
    start += num_tracks
# Out:
# getting from 0 to 100
# getting from 100 to 200
# getting from 200 to 300
# getting from 300 to 400
# getting from 400 to 500
# getting from 500 to 600
# getting from 600 to 700
# getting from 700 to 800
# getting from 800 to 900
# getting from 900 to 1000
# getting from 1000 to 1100
# getting from 1100 to 1200
# getting from 1200 to 1300
# getting from 1300 to 1400
# getting from 1400 to 1500
# getting from 1500 to 1600
# getting from 1600 to 1700
# getting from 1700 to 1800
# getting from 1800 to 1900
# getting from 1900 to 2000
# getting from 2000 to 2100
# getting from 2100 to 2200
# getting from 2200 to 2300
# getting from 2300 to 2400
# getting from 2400 to 2500
# getting from 2500 to 2600
# getting from 2600 to 2700
# getting from 2700 to 2800
# getting from 2800 to 2900
# getting from 2900 to 3000
# getting from 3000 to 3100
# getting from 3100 to 3200
# getting from 3200 to 3300
# getting from 3300 to 3400
# getting from 3400 to 3500
# getting from 3500 to 3600
# getting from 3600 to 3700
# getting from 3700 to 3800
# getting from 3800 to 3900
# getting from 3900 to 4000
# getting from 4000 to 4100
# getting from 4100 to 4200
# getting from 4200 to 4300
# getting from 4300 to 4400
# getting from 4400 to 4500
# getting from 4500 to 4600
# getting from 4600 to 4700
# getting from 4700 to 4800
# getting from 4800 to 4900
# getting from 4900 to 5000
# getting from 5000 to 5100
# getting from 5100 to 5200
# getting from 5200 to 5300
# getting from 5300 to 5400
# getting from 5400 to 5500
# getting from 5500 to 5600
# getting from 5600 to 5700
# getting from 5700 to 5800
# getting from 5800 to 5900
# getting from 5900 to 6000
# getting from 6000 to 6100
# getting from 6100 to 6200
# getting from 6200 to 6300
# getting from 6300 to 6400
# getting from 6400 to 6500
# getting from 6500 to 6600
# getting from 6600 to 6700
# getting from 6700 to 6800
# getting from 6800 to 6900
# getting from 6900 to 7000
# getting from 7000 to 7100
# getting from 7100 to 7200
# getting from 7200 to 7300
# getting from 7300 to 7400
# getting from 7400 to 7500
# getting from 7500 to 7600
# getting from 7600 to 7700
# getting from 7700 to 7800
# getting from 7800 to 7900
# getting from 7900 to 8000
# getting from 8000 to 8100
# getting from 8100 to 8200
# getting from 8200 to 8300
# getting from 8300 to 8400
# getting from 8400 to 8500
# getting from 8500 to 8600
# getting from 8600 to 8700
# getting from 8700 to 8800
# getting from 8800 to 8900
# getting from 8900 to 9000
# getting from 9000 to 9100
# getting from 9100 to 9200
# getting from 9200 to 9300
# getting from 9300 to 9400
# getting from 9400 to 9500
# getting from 9500 to 9600
# getting from 9600 to 9700
# getting from 9700 to 9800
# getting from 9800 to 9900
# getting from 9900 to 10000
# getting from 10000 to 10100
# getting from 10100 to 10200
# getting from 10200 to 10300
# getting from 10300 to 10400
# getting from 10400 to 10500
# getting from 10500 to 10600
# getting from 10600 to 10700
# getting from 10700 to 10800
# getting from 10800 to 10900
# getting from 10900 to 11000
# getting from 11000 to 11100
# getting from 11100 to 11200
# getting from 11200 to 11300
# getting from 11300 to 11400
# getting from 11400 to 11500
# getting from 11500 to 11600
# getting from 11600 to 11700
# getting from 11700 to 11800
# getting from 11800 to 11900
# getting from 11900 to 12000
# getting from 12000 to 12100
# getting from 12100 to 12200
# getting from 12200 to 12300
# getting from 12300 to 12400
# getting from 12400 to 12500
# getting from 12500 to 12600
# getting from 12600 to 12700
# getting from 12700 to 12800
# getting from 12800 to 12900
# getting from 12900 to 13000
# getting from 13000 to 13100
# getting from 13100 to 13200
# getting from 13200 to 13300
# getting from 13300 to 13400
# getting from 13400 to 13500
# getting from 13500 to 13600
# getting from 13600 to 13700
# getting from 13700 to 13800
# getting from 13800 to 13900

# %%
# Pick a random song_id from the dataset
# to have a look at how the audio features look like
features['6csZYoffpZ7iuSw83x2zVy']
# Out:
# {'danceability': 0.913,
#  'energy': 0.788,
#  'key': 10,
#  'loudness': -2.889,
#  'mode': 0,
#  'speechiness': 0.263,
#  'acousticness': 0.0546,
#  'instrumentalness': 0.00064,
#  'liveness': 0.168,
#  'valence': 0.544,
#  'tempo': 120.934,
#  'type': 'audio_features',
#  'id': '6csZYoffpZ7iuSw83x2zVy',
#  'uri': 'spotify:track:6csZYoffpZ7iuSw83x2zVy',
#  'track_href': 'https://api.spotify.com/v1/tracks/6csZYoffpZ7iuSw83x2zVy',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6csZYoffpZ7iuSw83x2zVy',
#  'duration_ms': 143314,
#  'time_signature': 4}

# %%
train_data = pd.DataFrame.from_dict(features, orient='index')
train_data = train_data.reset_index(drop=True).rename(columns={'id':'song_id'})

train_data
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.577   0.522    5    -6.594     0       0.0984        0.1300
# 1             0.556   0.538    8    -5.408     0       0.0382        0.0689
# 2             0.884   0.347    8    -8.227     0       0.3500        0.0150
# 3             0.936   0.523    5    -6.710     1       0.0597        0.2390
# 4             0.620   0.574    5    -7.788     0       0.0479        0.5690
# ...             ...     ...  ...       ...   ...          ...           ...
# 13875         0.798   0.627    9    -6.234     1       0.1110        0.2630
# 13876         0.777   0.721    6    -6.097     1       0.0719        0.0774
# 13877         0.913   0.788   10    -2.889     0       0.2630        0.0546
# 13878         0.599   0.734    3    -7.568     0       0.4130        0.1960
# 13879         0.740   0.595    1    -9.082     1       0.0623        0.4860
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000090    0.1420    0.119  159.772  audio_features
# 1              0.000000    0.1960    0.291  143.950  audio_features
# 2              0.000007    0.0871    0.376   75.016  audio_features
# 3              0.000000    0.1170    0.699  119.889  audio_features
# 4              0.000000    0.1900    0.357  100.023  audio_features
# ...                 ...       ...      ...      ...             ...
# 13875          0.000000    0.2110    0.762  149.989  audio_features
# 13876          0.000000    0.0801    0.665  161.976  audio_features
# 13877          0.000640    0.1680    0.544  120.934  audio_features
# 13878          0.000000    0.1870    0.133  211.842  audio_features
# 13879          0.000000    0.1630    0.316  131.960  audio_features
#
#                       song_id                                   uri  \
# 0      7wGoVu4Dady5GV0Sv4UIsx  spotify:track:7wGoVu4Dady5GV0Sv4UIsx
# 1      75ZvA4QfFiZvzhj2xkaWAh  spotify:track:75ZvA4QfFiZvzhj2xkaWAh
# 2      2fQrGHiQOvpL9UgPvtYy6G  spotify:track:2fQrGHiQOvpL9UgPvtYy6G
# 3      43ZyHQITOjhciSUUNPVRHc  spotify:track:43ZyHQITOjhciSUUNPVRHc
# 4      5tz69p7tJuGPeMGwNTxYuV  spotify:track:5tz69p7tJuGPeMGwNTxYuV
# ...                       ...                                   ...
# 13875  3js3wKPw8VxBWtcXtwyUnA  spotify:track:3js3wKPw8VxBWtcXtwyUnA
# 13876  4VVG3HBGaqSNZqIpmewIA6  spotify:track:4VVG3HBGaqSNZqIpmewIA6
# 13877  6csZYoffpZ7iuSw83x2zVy  spotify:track:6csZYoffpZ7iuSw83x2zVy
# 13878  0kHTkvGavvk2MjBTSUtOZx  spotify:track:0kHTkvGavvk2MjBTSUtOZx
# 13879  49VSioK272TASR4r9vRTuP  spotify:track:49VSioK272TASR4r9vRTuP
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/7wGoVu4Dady5...
# 1      https://api.spotify.com/v1/tracks/75ZvA4QfFiZv...
# 2      https://api.spotify.com/v1/tracks/2fQrGHiQOvpL...
# 3      https://api.spotify.com/v1/tracks/43ZyHQITOjhc...
# 4      https://api.spotify.com/v1/tracks/5tz69p7tJuGP...
# ...                                                  ...
# 13875  https://api.spotify.com/v1/tracks/3js3wKPw8VxB...
# 13876  https://api.spotify.com/v1/tracks/4VVG3HBGaqSN...
# 13877  https://api.spotify.com/v1/tracks/6csZYoffpZ7i...
# 13878  https://api.spotify.com/v1/tracks/0kHTkvGavvk2...
# 13879  https://api.spotify.com/v1/tracks/49VSioK272TA...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/7wGo...       218320
# 1      https://api.spotify.com/v1/audio-analysis/75Zv...       223347
# 2      https://api.spotify.com/v1/audio-analysis/2fQr...       220307
# 3      https://api.spotify.com/v1/audio-analysis/43Zy...       124056
# 4      https://api.spotify.com/v1/audio-analysis/5tz6...       250173
# ...                                                  ...          ...
# 13875  https://api.spotify.com/v1/audio-analysis/3js3...       195947
# 13876  https://api.spotify.com/v1/audio-analysis/4VVG...       205013
# 13877  https://api.spotify.com/v1/audio-analysis/6csZ...       143314
# 13878  https://api.spotify.com/v1/audio-analysis/0kHT...       223787
# 13879  https://api.spotify.com/v1/audio-analysis/49VS...       187273
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 13875               4
# 13876               4
# 13877               4
# 13878               4
# 13879               4
#
# [13880 rows x 18 columns]

# %%
# Save the data in a csv file
train_data.to_csv('train_data.csv', index=False)

# %% [markdown]
# - Θα κάνουμε το ίδιο και για τα κομμάτια που θα χρησιμοποιήσουμε για να προβλέψουμε το σθένος τους.
#
#
# - Αφού αντλήσουμε τα ακουστικά χαρακτηριστικά τους από το spotify, θα τα αποθηκεύσουμε σε ένα αρχείο ``spotify_data.csv``

# %%
spotify_ids = pd.read_table('spotify_ids.txt', names=['song_id'])
spotify_ids
# Out:
#                      song_id
# 0     7lPN2DXiMsVn7XUKtOW1CS
# 1     5QO79kh1waicV47BqGRL3g
# 2     0VjIjW4GlUZAMYd2vXMi3b
# 3     4MzXwWMhyBbmu6hOcLVD49
# 4     5Kskr9LcNYa0tpt5f0ZEJx
# ...                      ...
# 1157  4lUmnwRybYH7mMzf16xB0y
# 1158  1fzf9Aad4y1RWrmwosAK5y
# 1159  3E3pb3qH11iny6TFDJvsg5
# 1160  3yTkoTuiKRGL2VAlQd7xsC
# 1161  4JE6agBLHGA5TaF6FlqfBD
#
# [1162 rows x 1 columns]

# %%
audio_features = {}

spotify_track_ids = list(spotify_ids['song_id'].unique())
start = 0 
num_tracks = 100
while start < len(spotify_track_ids):
    print('getting from {} to {}'.format(start, start+num_tracks))
    
    tracks_batch = spotify_track_ids[start:start+num_tracks]
    features_batch = sp.audio_features(tracks_batch)
    
    # Use dictionary comprehension to update dictionary's content
    audio_features.update({track_id : track_features for track_id, track_features in zip(tracks_batch, features_batch)})
    
    start += num_tracks
# Out:
# getting from 0 to 100
# getting from 100 to 200
# getting from 200 to 300
# getting from 300 to 400
# getting from 400 to 500
# getting from 500 to 600
# getting from 600 to 700
# getting from 700 to 800
# getting from 800 to 900
# getting from 900 to 1000
# getting from 1000 to 1100
# getting from 1100 to 1200

# %%
spotify_data = pd.DataFrame.from_dict(audio_features, orient='index')
spotify_data = spotify_data.reset_index(drop=True).rename(columns={'id':'song_id'})

spotify_data
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.585   0.436   10    -8.761     1       0.0601       0.72100
# 1            0.680   0.826    0    -5.487     1       0.0309       0.02120
# 2            0.514   0.730    1    -5.934     1       0.0598       0.00146
# 3            0.731   0.573    4   -10.059     0       0.0544       0.40100
# 4            0.907   0.393    4    -7.636     0       0.0539       0.45100
# ...            ...     ...  ...       ...   ...          ...           ...
# 1157         0.596   0.650    9    -5.167     1       0.3370       0.13800
# 1158         0.588   0.850    4    -6.431     1       0.0318       0.16800
# 1159         0.754   0.660    0    -6.811     1       0.2670       0.17900
# 1160         0.584   0.836    0    -4.925     1       0.0790       0.05580
# 1161         0.331   0.450   10    -5.362     1       0.0340       0.36500
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000013    0.1050    0.132  143.874  audio_features
# 1             0.000012    0.5430    0.644  118.051  audio_features
# 2             0.000095    0.0897    0.334  171.005  audio_features
# 3             0.000052    0.1130    0.145  109.928  audio_features
# 4             0.000001    0.1350    0.202  104.949  audio_features
# ...                ...       ...      ...      ...             ...
# 1157          0.000000    0.1400    0.188  133.997  audio_features
# 1158          0.002020    0.0465    0.768   93.003  audio_features
# 1159          0.000000    0.1940    0.316   83.000  audio_features
# 1160          0.000000    0.0663    0.484  104.973  audio_features
# 1161          0.004640    0.2200    0.180  123.829  audio_features
#
#                      song_id                                   uri  \
# 0     7lPN2DXiMsVn7XUKtOW1CS  spotify:track:7lPN2DXiMsVn7XUKtOW1CS
# 1     5QO79kh1waicV47BqGRL3g  spotify:track:5QO79kh1waicV47BqGRL3g
# 2     0VjIjW4GlUZAMYd2vXMi3b  spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 3     4MzXwWMhyBbmu6hOcLVD49  spotify:track:4MzXwWMhyBbmu6hOcLVD49
# 4     5Kskr9LcNYa0tpt5f0ZEJx  spotify:track:5Kskr9LcNYa0tpt5f0ZEJx
# ...                      ...                                   ...
# 1157  4lUmnwRybYH7mMzf16xB0y  spotify:track:4lUmnwRybYH7mMzf16xB0y
# 1158  1fzf9Aad4y1RWrmwosAK5y  spotify:track:1fzf9Aad4y1RWrmwosAK5y
# 1159  3E3pb3qH11iny6TFDJvsg5  spotify:track:3E3pb3qH11iny6TFDJvsg5
# 1160  3yTkoTuiKRGL2VAlQd7xsC  spotify:track:3yTkoTuiKRGL2VAlQd7xsC
# 1161  4JE6agBLHGA5TaF6FlqfBD  spotify:track:4JE6agBLHGA5TaF6FlqfBD
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7lPN2DXiMsVn...
# 1     https://api.spotify.com/v1/tracks/5QO79kh1waic...
# 2     https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# 3     https://api.spotify.com/v1/tracks/4MzXwWMhyBbm...
# 4     https://api.spotify.com/v1/tracks/5Kskr9LcNYa0...
# ...                                                 ...
# 1157  https://api.spotify.com/v1/tracks/4lUmnwRybYH7...
# 1158  https://api.spotify.com/v1/tracks/1fzf9Aad4y1R...
# 1159  https://api.spotify.com/v1/tracks/3E3pb3qH11in...
# 1160  https://api.spotify.com/v1/tracks/3yTkoTuiKRGL...
# 1161  https://api.spotify.com/v1/tracks/4JE6agBLHGA5...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/7lPN...       242014
# 1     https://api.spotify.com/v1/audio-analysis/5QO7...       215627
# 2     https://api.spotify.com/v1/audio-analysis/0VjI...       200040
# 3     https://api.spotify.com/v1/audio-analysis/4MzX...       205090
# 4     https://api.spotify.com/v1/audio-analysis/5Ksk...       205458
# ...                                                 ...          ...
# 1157  https://api.spotify.com/v1/audio-analysis/4lUm...       257428
# 1158  https://api.spotify.com/v1/audio-analysis/1fzf...       187310
# 1159  https://api.spotify.com/v1/audio-analysis/3E3p...       209299
# 1160  https://api.spotify.com/v1/audio-analysis/3yTk...       202204
# 1161  https://api.spotify.com/v1/audio-analysis/4JE6...       218755
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1157               4
# 1158               4
# 1159               4
# 1160               4
# 1161               4
#
# [1162 rows x 18 columns]

# %%
# Save the data in a csv file
spotify_data.to_csv('spotify_data.csv', index=False)
